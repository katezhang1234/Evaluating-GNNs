         0.8806818181818182, 0.8920454545454546, 0.9090909090909091, 0.9375]

GIN = [0.48863636363636365, 0.5056818181818182, 0.5397727272727273, 0.4943181818181818, 0.5454545454545454, 0.5852272727272727, 
 0.5170454545454546, 0.6136363636363636, 0.625, 0.6534090909090909, 0.6931818181818182, 0.6818181818181818, 0.6818181818181818, 
 0.7443181818181818, 0.8011363636363636, 0.6818181818181818, 0.6363636363636364, 0.7215909090909091, 0.8181818181818182, 
 0.7215909090909091, 0.8636363636363636, 0.8579545454545454, 0.8579545454545454, 0.9034090909090909, 0.8636363636363636, 
 0.8920454545454546, 0.7329545454545454, 0.8409090909090909, 0.8409090909090909, 0.9034090909090909]

# %%
epochs = list(range(1, 31))
plt.figure(figsize=(10, 6))

plt.plot(epochs, MLP, label="MLP")
plt.plot(epochs, GCN, label="GCN")
plt.plot(epochs, GAT, label="GAT")
plt.plot(epochs, SAGE, label="GraphSAGE")
plt.plot(epochs, GATv2, label="GATv2")
plt.plot(epochs, GIN, label="GIN")

# Graph labels
plt.xlabel("Epochs")
plt.ylabel("Train Accuracy")
plt.title("Comparison of Model Training Accuracies")
plt.legend()
plt.show()

# %% [markdown]
# ## Train Losses

# %%
MLP_Loss = [0.6905, 0.8076, 2.2031, 0.8077, 0.8216, 0.7205, 0.6335, 0.6177, 0.5833, 0.5778, 
 0.544, 0.512, 0.5031, 0.4518, 0.4149, 0.4103, 0.399, 0.3666, 0.3185, 0.3071, 
 0.3248, 0.3265, 0.2804, 0.2563, 0.2919, 0.2831, 0.2314, 0.2429, 0.2461, 0.2084]

# %%
GCN_Loss = [1.4187376499176025, 0.7000643014907837, 0.7196148633956909, 0.6503098011016846, 0.6178621649742126, 0.5649287700653076, 
       0.5391440391540527, 0.5032091736793518, 0.5301945209503174, 0.5679936408996582, 0.4971117079257965, 0.444649338722229, 
       0.3800346851348877, 0.3549422323703766, 0.3271920680999756, 0.380992591381073, 0.3853329122066498, 0.3083740472793579, 
       0.2648079991340637, 0.2547679543495178, 0.25352394580841064, 0.25948384404182434, 0.3064925968647003, 0.29915037751197815, 
       0.3149014711380005, 0.2842755615711212, 0.28613707423210144, 0.25602778792381287, 0.3043126165866852, 0.2561601996421814]


GAT_Loss = [1.039595127105713, 0.6731577515602112, 0.6630069613456726, 0.6007978916168213, 0.547269880771637, 0.51531583070755, 
       0.4831734597682953, 0.4472180902957916, 0.49289649724960327, 0.4536258578300476, 0.35288724303245544, 0.33884620666503906, 
            0.3419029116630554, 0.32646414637565613, 0.3384535312652588, 0.4872859716415405, 0.6491116285324097, 0.3573869466781616, 
       0.33415278792381287, 0.321435809135437, 0.3020792305469513, 0.25532785058021545, 0.2528434097766876, 0.2759120762348175, 
       0.3630507290363312, 0.3652229607105255, 0.38433295488357544, 0.40573975443840027, 0.3131416440010071, 0.3197799026966095]


SAGE_Loss = [0.647959291934967, 0.6954516768455505, 0.6845453381538391, 0.6560793519020081, 0.6263296008110046, 0.5962755084037781, 
        0.7756255269050598, 0.5888439416885376, 0.5971038937568665, 0.6363523006439209, 0.5280169248580933, 0.43962740898132324, 
        0.3476390838623047, 0.6987907886505127, 0.5809485912322998, 0.4848739504814148, 0.40031668543815613, 0.34869059920310974, 
        0.310319185256958, 0.3428199887275696, 0.3518427610397339, 0.3776145577430725, 0.30985110998153687, 0.3998360335826874, 
        0.43906065821647644, 0.33997973799705505, 0.4211178719997406, 0.3412739932537079, 0.3700847327709198, 0.37376171350479126]

# %%
GATv2_Loss = [0.7985395193099976, 0.7628606557846069, 0.6557362079620361, 0.619372546672821, 0.5932446122169495, 0.5681208372116089, 
              0.569699227809906, 0.5020751357078552, 0.4354499578475952, 0.3928191661834717, 0.3794400691986084, 0.3711913228034973, 
              0.30170905590057373, 0.3737911283969879, 0.2848697304725647, 0.3139449656009674, 0.290608674287796, 0.2871592938899994, 
              0.339193195104599, 0.33838406205177307, 0.36097851395606995, 0.3796072006225586, 0.3129783570766449, 0.2827671468257904, 
              0.29160526394844055, 0.38110774755477905, 0.3612786531448364, 0.4181564450263977, 0.37583664059638977, 0.3203924596309662]

GIN_Loss = [0.906130313873291, 0.7704814076423645, 0.9181657433509827, 0.675976037979126, 0.6553087830543518, 0.6728444695472717, 
            0.6201332807540894, 0.574739933013916, 0.5591239333152771, 0.5318834185600281, 0.47776275873184204, 0.47336944937705994, 
            0.4073067903518677, 0.2922782599925995, 0.7203953266143799, 0.6858288645744324, 0.3926823139190674, 0.40502628684043884, 
            0.46539005637168884, 0.32696324586868286, 0.29675665497779846, 0.27460139989852905, 0.26552972197532654, 0.25863316655158997, 
            0.32905808091163635, 0.6676516532897949, 0.3564237952232361, 0.4047040045261383, 0.26178911328315735, 0.2882320284843445]

# %%
epochs = list(range(1, 31))
plt.figure(figsize=(10, 6))

plt.plot(epochs, MLP_Loss, label="MLP")
plt.plot(epochs, GCN_Loss, label="GCN")
plt.plot(epochs, GAT_Loss, label="GAT")
plt.plot(epochs, SAGE_Loss, label="GraphSAGE")
plt.plot(epochs, GATv2_Loss, label="GATv2")
plt.plot(epochs, GIN_Loss, label="GIN")

# Graph labels
plt.xlabel("Epochs")
plt.ylabel("Train Loss")
plt.title("Comparison of Model Training Losses")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(epochs, GCN_Loss, label="GCN")
plt.plot(epochs, GAT_Loss, label="GAT")
plt.plot(epochs, SAGE_Loss, label="GraphSAGE")
plt.plot(epochs, GATv2_Loss, label="GATv2")
plt.plot(epochs, GIN_Loss, label="GIN")

# Graph labels
plt.xlabel("Epochs")
plt.ylabel("Train Loss")
plt.title("Comparison of GNN Training Losses")
plt.legend()
plt.show()
