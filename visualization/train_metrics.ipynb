GIN = [0.48863636363636365, 0.5227272727272727, 0.5454545454545454, 0.6306818181818182, 0.5795454545454546, 0.6193181818181818, 0.7102272727272727, 0.7613636363636364, 0.7670454545454546, 0.8181818181818182, 0.7954545454545454, 0.8295454545454546, 0.8693181818181818, 0.8579545454545454, 0.8181818181818182, 0.7954545454545454, 0.8125, 0.8977272727272727, 0.875, 0.8295454545454546, 0.8636363636363636, 0.8920454545454546, 0.9431818181818182, 0.9318181818181818, 0.9204545454545454, 0.9431818181818182, 0.9375, 0.9261363636363636, 0.9204545454545454, 0.9204545454545454]

# %%
epochs = list(range(1, 31))
plt.figure(figsize=(10, 6))

plt.plot(epochs, MLP, label="MLP")
plt.plot(epochs, GCN, label="GCN")
plt.plot(epochs, GAT, label="GAT")
plt.plot(epochs, SAGE, label="GraphSAGE")
plt.plot(epochs, GATv2, label="GATv2")
plt.plot(epochs, GIN, label="GIN")

plt.ylim(0, 1.0) 

# Graph labels
plt.xlabel("Epochs")
plt.ylabel("Train Accuracy")
plt.title("Comparison of Model Training Accuracies")
plt.legend()
plt.show()

# %% [markdown]
# ## Train Losses

# %%
MLP_Loss = [0.6905, 0.8076, 2.2031, 0.8077, 0.8216, 0.7205, 0.6335, 0.6177, 0.5833, 0.5778, 
 0.544, 0.512, 0.5031, 0.4518, 0.4149, 0.4103, 0.399, 0.3666, 0.3185, 0.3071, 
 0.3248, 0.3265, 0.2804, 0.2563, 0.2919, 0.2831, 0.2314, 0.2429, 0.2461, 0.2084]

# %%
GCN_Loss = [0.6563023328781128, 0.646091103553772, 0.6244135499000549, 0.6068215370178223, 0.5594291090965271, 0.5205636024475098, 0.4772014915943146, 0.43555283546447754, 0.41686657071113586, 0.3752005398273468, 0.359201043844223, 0.35227489471435547, 0.3376682996749878, 0.3184281289577484, 0.29114964604377747, 0.26706427335739136, 0.2875450849533081, 0.26279133558273315, 0.2522759735584259, 0.2735648453235626, 0.2749232053756714, 0.27841266989707947, 0.29163438081741333, 0.2764323651790619, 0.29146113991737366, 0.2695038318634033, 0.2672603726387024, 0.2667190134525299, 0.2720152735710144, 0.26623332500457764]

GAT_Loss = [0.6432201862335205, 0.5898349285125732, 0.5667641758918762, 0.5065496563911438, 0.4522749185562134, 0.42957404255867004, 0.3718641996383667, 0.3305729329586029, 0.30885639786720276, 0.31076234579086304, 0.3033578395843506, 0.30154940485954285, 0.2964644730091095, 0.2791544198989868, 0.2669602930545807, 0.30885645747184753, 0.3092144727706909, 0.312315970659256, 0.3616067171096802, 0.29315707087516785, 0.2811645269393921, 0.2720279395580292, 0.25991135835647583, 0.2630392611026764, 0.38380682468414307, 0.33014094829559326, 0.29288601875305176, 0.3285551965236664, 0.3594090938568115, 0.32112446427345276]

SAGE_Loss = [0.6717262268066406, 0.6389299631118774, 0.6027316451072693, 0.5710391402244568, 0.5291681885719299, 0.5047890543937683, 0.46804115176200867, 0.4790535867214203, 0.4145767092704773, 0.3985165059566498, 0.430018812417984, 0.3762654960155487, 0.3940664529800415, 0.3364228308200836, 0.3520980179309845, 0.2948630452156067, 0.29012995958328247, 0.3138717710971832, 0.31800538301467896, 0.3266488015651703, 0.3184086084365845, 0.30916091799736023, 0.29177847504615784, 0.2893545925617218, 0.28981414437294006, 0.29601162672042847, 0.2994636297225952, 0.30962124466896057, 0.3106177747249603, 0.30753418803215027]

# %%
GATv2_Loss = [0.641937792301178, 0.6208340525627136, 0.6030746698379517, 0.5659998059272766, 0.5185535550117493, 0.48231980204582214, 0.45305538177490234, 0.4233831465244293, 0.3895037770271301, 0.3518603444099426, 0.3588535785675049, 0.3167814314365387, 0.30507034063339233, 0.28570088744163513, 0.27608630061149597, 0.28580400347709656, 0.28477758169174194, 0.3879169523715973, 0.26769760251045227, 0.262275367975235, 0.3341398239135742, 0.3102111518383026, 0.2973780930042267, 0.32734620571136475, 0.29863783717155457, 0.30850711464881897, 0.29823529720306396, 0.3078530728816986, 0.3249729871749878, 0.2980639338493347]

GIN_Loss = [0.7459852695465088, 0.724057674407959, 0.6522520184516907, 0.6560828685760498, 0.6351986527442932, 0.5916784405708313, 0.5714874267578125, 0.5414575934410095, 0.5332197546958923, 0.5093086361885071, 0.5021305680274963, 0.47347328066825867, 0.4602445960044861, 0.47383567690849304, 0.5934433937072754, 0.5584204792976379, 0.4692600965499878, 0.5950526595115662, 0.47806984186172485, 0.5401349663734436, 0.5188544988632202, 0.5187087059020996, 0.48825204372406006, 0.4688810706138611, 0.4781080484390259, 0.5494053363800049, 0.5106704831123352, 0.45409247279167175, 0.5294970870018005, 0.5179192423820496]

# %%
epochs = list(range(1, 31))
plt.figure(figsize=(10, 6))

plt.plot(epochs, MLP_Loss, label="MLP")
plt.plot(epochs, GCN_Loss, label="GCN")
plt.plot(epochs, GAT_Loss, label="GAT")
plt.plot(epochs, SAGE_Loss, label="GraphSAGE")
plt.plot(epochs, GATv2_Loss, label="GATv2")
plt.plot(epochs, GIN_Loss, label="GIN")

# Graph labels
plt.xlabel("Epochs")
plt.ylabel("Train Loss")
plt.title("Comparison of Model Training Losses")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(epochs, GCN_Loss, label="GCN")
plt.plot(epochs, GAT_Loss, label="GAT")
plt.plot(epochs, SAGE_Loss, label="GraphSAGE")
plt.plot(epochs, GATv2_Loss, label="GATv2")
plt.plot(epochs, GIN_Loss, label="GIN")

# Graph labels
plt.xlabel("Epochs")
plt.ylabel("Train Loss")
plt.title("Comparison of GNN Training Losses")
plt.legend()
plt.show()
